# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip3 install gpt-2-simple
# Out:
# ...
#      |████████████████████████████████| 645kB 7.3MB/s
# ...
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.7-cp36-none-any.whl size=23557 sha256=1779efb90120927b1f9b5255f44c68576d2f16064fa3efd9bee9f1c73c1fd9de
#   Stored in directory: /root/.cache/pip/wheels/28/7f/89/1253cc7ae7fd1cdf130fa146ab17314fd2a5a6d48ccf21dec5
# Successfully built gpt-2-simple
# ...

# %%
import gpt_2_simple as gpt2

model_name = "345M"
gpt2.download_gpt2(model_name=model_name)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# Fetching checkpoint: 1.05Mit [00:00, 210Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 82.4Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 271Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:11, 119Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 222Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 117Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 155Mit/s]

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              '/content/drive/My Drive/SI671/project/data/ShortStories',
              model_name=model_name,
              steps=1000,
              save_every=100,
            #   restore_from ="/content/drive/My Drive/SI671/project/weights/ss/run1",
              checkpoint_dir ="/content/drive/My Drive/SI671/project/weights/ss")   # steps is max number of training steps
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/345M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:17<00:00, 17.13s/it]
# dataset has 3259143 tokens
# Training...
# [1 | 92.51] loss=3.02 avg=3.02
# [2 | 171.69] loss=2.90 avg=2.96
# [3 | 250.81] loss=2.83 avg=2.91
# ...
